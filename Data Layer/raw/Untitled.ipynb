# %%
# !pip install pandas numpy matplotlib --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install pandas numpy matplotlib seaborn --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 874.9 kB/s eta 0:00:001m902.6 kB/s eta 0:00:01
# ...

# %%
# %pip install pandas numpy matplotlib seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 1.4 MB/s  0:00:08 eta 0:00:010:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 1.4 MB/s  0:00:11 eta 0:00:010:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 1.4 MB/s  0:00:06 eta 0:00:010:01:01
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 3.1/5.0 MB 1.5 MB/s eta 0:00:02:03

# %%
import sys
print(sys.executable)
# Out:
# /home/igorjus/.local/share/pipx/venvs/jupyterlab/bin/python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_raw_full = pd.read_csv('campeonato-brasileiro-full.csv')

# %%
df_raw_full.head(10)
# Out:
#    ID  rodata        data   hora       mandante    visitante  \
# 0   1       1  29/03/2003  16:00        Guarani        Vasco
# 1   2       1  29/03/2003  16:00   Athletico-PR       Gremio
# 2   3       1  30/03/2003  16:00       Flamengo     Coritiba
# 3   4       1  30/03/2003  16:00          Goias     Paysandu
# 4   5       1  30/03/2003  16:00  Internacional  Ponte Preta
# 5   6       1  30/03/2003  16:00       Criciuma   Fluminense
# 6   7       1  30/03/2003  16:00      Juventude    Sao Paulo
# 7   8       1  30/03/2003  16:00      Fortaleza        Bahia
# 8   9       1  30/03/2003  16:00       Cruzeiro  Sao Caetano
# 9  10       1  30/03/2003  16:00        Vitoria  Figueirense
#
#   formacao_mandante formacao_visitante tecnico_mandante tecnico_visitante  \
# 0               NaN                NaN              NaN               NaN
# 1               NaN                NaN              NaN               NaN
# ...
